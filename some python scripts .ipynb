# %%
import pandas as pd
df=pd.read_clipboard()

# %%
df
# Out:
#    iso_code continent     location        date  population
# 0       AFG      Asia  Afghanistan  03-01-2020    41128772
# 1       AFG      Asia  Afghanistan  04-01-2020    41128772
# 2       AFG      Asia  Afghanistan  05-01-2020    41128772
# 3       AFG      Asia  Afghanistan  06-01-2020    41128772
# 4       AFG      Asia  Afghanistan  07-01-2020    41128772
# 5       AFG      Asia  Afghanistan  08-01-2020    41128772
# 6       AFG      Asia  Afghanistan  09-01-2020    41128772
# 7       AFG      Asia  Afghanistan  10-01-2020    41128772
# 8       AFG      Asia  Afghanistan  11-01-2020    41128772
# 9       AFG      Asia  Afghanistan  12-01-2020    41128772
# 10      AFG      Asia  Afghanistan  13-01-2020    41128772
# 11      AFG      Asia  Afghanistan  14-01-2020    41128772
# 12      AFG      Asia  Afghanistan  15-01-2020    41128772
# 13      AFG      Asia  Afghanistan  16-01-2020    41128772
# 14      AFG      Asia  Afghanistan  17-01-2020    41128772
# ...

# %%
pip install plyer
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from plyer import notification
import time

# %%
if __name__=="__main__":
    while True:
        notification.notify(
        title="Alert!!",
        message='please be careful about malwares and thefts',
        timeout=100)
        time.sleep(3600)
